# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("comprehensive_student_clustering_dataset.csv")

# %%
df
# Out:
#     StudentID  Age  Gender    County                 Program  ProgramType  \
# 0    STU-0001   17  Female    Kisumu            Data Science  Certificate
# 1    STU-0002   34  Female  Kakamega            Data Science  Certificate
# 2    STU-0003   41    Male    Kisumu   Full Stack JavaScript     Bootcamp
# 3    STU-0004   25    Male  Kakamega            UI/UX Design  Certificate
# 4    STU-0005   19    Male     Kisii  Blockchain Development     Bootcamp
# ..        ...  ...     ...       ...                     ...          ...
# 495  STU-0496   40    Male    Kisumu            Data Science  Certificate
# 496  STU-0497   42    Male  Machakos   AI & Machine Learning      Diploma
# 497  STU-0498   22    Male  Machakos  Blockchain Development     Bootcamp
# 498  STU-0499   26    Male   Nairobi         Cloud Computing  Certificate
# 499  STU-0500   24    Male   Mombasa            UI/UX Design  Certificate
#
#     LearningMode EducationLevel EmploymentStatus   PaymentPlan  ...  \
# 0         Online    High School          Student  Installments  ...
# 1       Physical         Degree         Employed     Sponsored  ...
# 2         Hybrid         Degree       Unemployed  Installments  ...
# 3         Hybrid         Degree    Self-employed  Full Payment  ...
# 4       Physical    High School         Employed  Full Payment  ...
# ..           ...            ...              ...           ...  ...
# 495       Hybrid        Diploma         Employed  Installments  ...
# 496     Physical         Degree    Self-employed     Sponsored  ...
# 497       Online        Diploma         Employed     Sponsored  ...
# 498     Physical         Degree    Self-employed  Installments  ...
# 499       Online    High School         Employed     Sponsored  ...
#
#     VideoLessonsWatched LabCompletionRatePercent  PeerCollaborationScore  \
# 0                    16                       51                       2
# 1                    94                       64                      10
# 2                    68                       56                       1
# 3                    72                       58                      10
# 4                    48                       39                      10
# ..                  ...                      ...                     ...
# 495                  96                       61                       8
# 496                  28                       71                       2
# 497                  76                       50                       5
# 498                  81                       79                       9
# 499                  97                       63                       9
#
#      CommunicationScore  ProblemSolvingScore  ConfidenceLevel1To10  \
# 0                     6                    5                    10
# 1                     3                    7                     3
# 2                     2                    5                     3
# 3                     6                    9                     1
# 4                     9                    3                    10
# ..                  ...                  ...                   ...
# 495                   6                    4                     9
# 496                   8                    5                     2
# 497                   7                    4                     8
# 498                   8                    4                     4
# 499                   6                    5                     4
#
#      EngagementLevel  AttendanceStatus  DropoutRiskLevel    FinalClusterHint
# 0             Medium         Irregular              High  Struggling Learner
# 1             Medium          Moderate            Medium   Practical Builder
# 2             Medium          Moderate            Medium      Casual Learner
# 3             Medium          Moderate               Low     Career Switcher
# 4             Medium          Moderate              High  Struggling Learner
# ..               ...               ...               ...                 ...
# 495              Low         Irregular            Medium      Casual Learner
# 496           Medium        Consistent               Low     Career Switcher
# 497           Medium         Irregular            Medium      Casual Learner
# 498           Medium        Consistent               Low     Career Switcher
# 499             High          Moderate            Medium     Career Switcher
#
# [500 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   StudentID                      500 non-null    object
#  1   Age                            500 non-null    int64
#  2   Gender                         500 non-null    object
#  3   County                         500 non-null    object
#  4   Program                        500 non-null    object
#  5   ProgramType                    500 non-null    object
#  6   LearningMode                   500 non-null    object
#  7   EducationLevel                 500 non-null    object
#  8   EmploymentStatus               500 non-null    object
#  9   PaymentPlan                    500 non-null    object
#  10  DeviceType                     500 non-null    object
#  11  InternetQuality                500 non-null    object
#  12  PreviousCodingExperienceYears  500 non-null    float64
#  13  WeeklyStudyHours               500 non-null    int64
#  14  AttendanceRatePercent          500 non-null    int64
#  15  AssignmentsSubmitted           500 non-null    int64
#  16  AssignmentsLate                500 non-null    int64
#  17  AverageQuizScore               500 non-null    int64
#  18  AverageProjectScore            500 non-null    int64
#  19  ForumPosts                     500 non-null    int64
#  20  MentorSessionsAttended         500 non-null    int64
#  21  GitHubCommits                  500 non-null    int64
#  22  ProjectsCompleted              500 non-null    int64
#  23  PreferredProgrammingLanguage   500 non-null    object
#  24  CareerGoal                     500 non-null    object
#  25  AdmissionSource                500 non-null    object
#  26  ProjectCategory                500 non-null    object
#  27  MonthlyFeePaidKES              500 non-null    int64
#  28  OutstandingBalanceKES          500 non-null    int64
#  29  ScholarshipPercent             500 non-null    int64
#  30  DaysSinceLastLogin             500 non-null    int64
#  31  LoginFrequencyPerWeek          500 non-null    int64
#  32  VideoLessonsWatched            500 non-null    int64
#  33  LabCompletionRatePercent       500 non-null    int64
#  34  PeerCollaborationScore         500 non-null    int64
#  35  CommunicationScore             500 non-null    int64
#  36  ProblemSolvingScore            500 non-null    int64
#  37  ConfidenceLevel1To10           500 non-null    int64
#  38  EngagementLevel                500 non-null    object
#  39  AttendanceStatus               500 non-null    object
#  40  DropoutRiskLevel               500 non-null    object
#  41  FinalClusterHint               500 non-null    object
# dtypes: float64(1), int64(22), object(19)
# memory usage: 164.2+ KB

# %%
numerical_df = df.select_dtypes(include = ["float64","int64"])
numerical_df
# Out:
#      Age  PreviousCodingExperienceYears  WeeklyStudyHours  \
# 0     17                            1.7                 9
# 1     34                            3.4                12
# 2     41                            2.4                10
# 3     25                            0.6                22
# 4     19                            1.2                 4
# ..   ...                            ...               ...
# 495   40                            0.6                13
# 496   42                            0.1                 8
# 497   22                            1.6                 9
# 498   26                            1.4                17
# 499   24                            0.8                16
#
#      AttendanceRatePercent  AssignmentsSubmitted  AssignmentsLate  \
# 0                       51                     7                3
# 1                       72                    12                3
# 2                       74                    16                1
# 3                       76                    15                1
# 4                       59                     8                3
# ..                     ...                   ...              ...
# 495                     50                    12                7
# 496                     80                    13                0
# 497                     49                    12                8
# 498                     88                    15                1
# 499                     72                    11                3
#
#      AverageQuizScore  AverageProjectScore  ForumPosts  \
# 0                  34                   48          21
# 1                  82                   73          42
# 2                  49                   53           8
# 3                  82                   61          34
# 4                  32                   39          14
# ..                ...                  ...         ...
# 495                43                   57          10
# 496                59                   55          35
# 497                59                   52          13
# 498                50                   61          42
# 499                61                   52          44
#
#      MentorSessionsAttended  ...  OutstandingBalanceKES  ScholarshipPercent  \
# 0                         1  ...                  24393                  50
# 1                         4  ...                  41887                  10
# 2                         8  ...                  37050                  10
# 3                        12  ...                   3093                   0
# 4                         1  ...                  35535                   0
# ..                      ...  ...                    ...                 ...
# 495                       3  ...                  10105                  50
# 496                      13  ...                  35028                  30
# 497                       5  ...                  38340                  30
# 498                      14  ...                   4669                  30
# 499                      11  ...                  49422                  20
#
#      DaysSinceLastLogin  LoginFrequencyPerWeek  VideoLessonsWatched  \
# 0                    12                      3                   16
# 1                     7                      8                   94
# 2                    11                      6                   68
# 3                     5                      8                   72
# 4                    27                      2                   48
# ..                  ...                    ...                  ...
# 495                   5                      5                   96
# 496                   7                      7                   28
# 497                  10                      2                   76
# 498                   8                      2                   81
# 499                   9                      5                   97
#
#      LabCompletionRatePercent  PeerCollaborationScore  CommunicationScore  \
# 0                          51                       2                   6
# 1                          64                      10                   3
# 2                          56                       1                   2
# 3                          58                      10                   6
# 4                          39                      10                   9
# ..                        ...                     ...                 ...
# 495                        61                       8                   6
# 496                        71                       2                   8
# 497                        50                       5                   7
# 498                        79                       9                   8
# 499                        63                       9                   6
#
#      ProblemSolvingScore  ConfidenceLevel1To10
# 0                      5                    10
# 1                      7                     3
# 2                      5                     3
# 3                      9                     1
# 4                      3                    10
# ..                   ...                   ...
# 495                    4                     9
# 496                    5                     2
# 497                    4                     8
# 498                    4                     4
# 499                    5                     4
#
# [500 rows x 23 columns]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_df)

# %%
scaled_data
# Out:
# array([[-1.76760295,  0.05842258, -0.67149195, ...,  0.12053001,
#         -0.70079013,  1.55348481],
#        [ 0.5719525 ,  1.44943649, -0.30615357, ..., -0.93060381,
#          0.25919635, -0.81360132],
#        [ 1.53529886,  0.63119302, -0.54971249, ..., -1.28098175,
#         -0.70079013, -0.81360132],
#        ...,
#        [-1.07949841, -0.02340176, -0.67149195, ...,  0.47090795,
#         -1.18078337,  0.87717449],
#        [-0.52901477, -0.18705046,  0.30274374, ...,  0.82128589,
#         -1.18078337, -0.47544616],
#        [-0.80425659, -0.67799654,  0.18096428, ...,  0.12053001,
#         -0.70079013, -0.47544616]], shape=(500, 23))

# %%
kmeans = KMeans(n_clusters = 6,random_state = 42)
df["Clusters"] = kmeans.fit_predict(scaled_data)
# Out:
# C:\Users\USER\Music\New folder\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
df
# Out:
#     StudentID  Age  Gender    County                 Program  ProgramType  \
# 0    STU-0001   17  Female    Kisumu            Data Science  Certificate
# 1    STU-0002   34  Female  Kakamega            Data Science  Certificate
# 2    STU-0003   41    Male    Kisumu   Full Stack JavaScript     Bootcamp
# 3    STU-0004   25    Male  Kakamega            UI/UX Design  Certificate
# 4    STU-0005   19    Male     Kisii  Blockchain Development     Bootcamp
# ..        ...  ...     ...       ...                     ...          ...
# 495  STU-0496   40    Male    Kisumu            Data Science  Certificate
# 496  STU-0497   42    Male  Machakos   AI & Machine Learning      Diploma
# 497  STU-0498   22    Male  Machakos  Blockchain Development     Bootcamp
# 498  STU-0499   26    Male   Nairobi         Cloud Computing  Certificate
# 499  STU-0500   24    Male   Mombasa            UI/UX Design  Certificate
#
#     LearningMode EducationLevel EmploymentStatus   PaymentPlan  ...  \
# 0         Online    High School          Student  Installments  ...
# 1       Physical         Degree         Employed     Sponsored  ...
# 2         Hybrid         Degree       Unemployed  Installments  ...
# 3         Hybrid         Degree    Self-employed  Full Payment  ...
# 4       Physical    High School         Employed  Full Payment  ...
# ..           ...            ...              ...           ...  ...
# 495       Hybrid        Diploma         Employed  Installments  ...
# 496     Physical         Degree    Self-employed     Sponsored  ...
# 497       Online        Diploma         Employed     Sponsored  ...
# 498     Physical         Degree    Self-employed  Installments  ...
# 499       Online    High School         Employed     Sponsored  ...
#
#     LabCompletionRatePercent PeerCollaborationScore  CommunicationScore  \
# 0                         51                      2                   6
# 1                         64                     10                   3
# 2                         56                      1                   2
# 3                         58                     10                   6
# 4                         39                     10                   9
# ..                       ...                    ...                 ...
# 495                       61                      8                   6
# 496                       71                      2                   8
# 497                       50                      5                   7
# 498                       79                      9                   8
# 499                       63                      9                   6
#
#      ProblemSolvingScore  ConfidenceLevel1To10  EngagementLevel  \
# 0                      5                    10           Medium
# 1                      7                     3           Medium
# 2                      5                     3           Medium
# 3                      9                     1           Medium
# 4                      3                    10           Medium
# ..                   ...                   ...              ...
# 495                    4                     9              Low
# 496                    5                     2           Medium
# 497                    4                     8           Medium
# 498                    4                     4           Medium
# 499                    5                     4             High
#
#      AttendanceStatus  DropoutRiskLevel    FinalClusterHint  Clusters
# 0           Irregular              High  Struggling Learner         2
# 1            Moderate            Medium   Practical Builder         4
# 2            Moderate            Medium      Casual Learner         5
# 3            Moderate               Low     Career Switcher         4
# 4            Moderate              High  Struggling Learner         2
# ..                ...               ...                 ...       ...
# 495         Irregular            Medium      Casual Learner         1
# 496        Consistent               Low     Career Switcher         1
# 497         Irregular            Medium      Casual Learner         2
# 498        Consistent               Low     Career Switcher         4
# 499          Moderate            Medium     Career Switcher         4
#
# [500 rows x 43 columns]
